# %% [markdown]
#  ## LOGIN

# %%
### YYY
import time
from selenium import webdriver
from selenium.webdriver import ChromeOptions, Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait

# Set up Chrome options
chrome_options = ChromeOptions()
chrome_options.add_argument("--start-maximized")
chrome_options.add_experimental_option("excludeSwitches", ["enable-automation"])

# Start ChromeDriver
driver = webdriver.Chrome(options=chrome_options)

# Open the Twitter login page
url = 'https://x.com/i/flow/login'
driver.get(url)

# Your Twitter credentials
username_value  = 'JesseJin1998'
password_value  = 'Jesse1998.'

try:
    # Locate the username input field
    username = WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.CSS_SELECTOR, 'input[autocomplete="username"]')))
    username.send_keys(username_value)
    username.send_keys(Keys.ENTER)

    # Locate the password input field
    password = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.CSS_SELECTOR, 'input[name="password"]')))
    password.send_keys(password_value)
    password.send_keys(Keys.ENTER)

    # Wait for the profile icon to be visible as an indication of a successful login
    WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.CSS_SELECTOR, 'div[data-testid="SideNav_AccountSwitcher_Button"]')))
    print("Logged in successfully.")
    driver.save_screenshot('login_success.png')

except Exception as e:
    print(f"Error during login: {e}")
    driver.save_screenshot('login_error.png')
    with open("login_error.html", "w", encoding="utf-8") as f:
        f.write(driver.page_source)

finally:
    # Close the driver after a delay
    time.sleep(10)
    driver.quit()

# %%
##good
import time
from selenium import webdriver
from selenium.webdriver import ChromeOptions, Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.wddddebdriver.support.wait import WebDriverWait

# Set up Chrome options
chrome_options = ChromeOptions()
chrome_options.add_argument("--start-maximized")
chrome_options.add_experimental_option("excludeSwitches", ["enable-automation"])

# Start ChromeDriver
driver = webdriver.Chrome(options=chrome_options)

# Open the Twitter login page
url = 'https://x.com/i/flow/login'
driver.get(url)

# Your Twitter credentials
username_value  = 'JesseJin1998'
password_value  = 'Jesse1998.'

username = WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.CSS_SELECTOR, 'input[autocomplete="username"]')))
username.send_keys(username_value)
username.send_keys(Keys.ENTER)

# Locate the password input field
password = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.CSS_SELECTOR, 'input[name="password"]')))
password.send_keys(password_value)
password.send_keys(Keys.ENTER)

# Wait for the profile icon to be visible as an indication of a successful login
WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.CSS_SELECTOR, 'div[data-testid="SideNav_AccountSwitcher_Button"]')))
print("Logged in successfully.")

driver.get("https://www.selenium.dev/selenium/web/index.html")





# 关闭WebDriver

# %% [markdown]
# ## next

# %%
## Break Down
import time
from datetime import datetime

from selenium import webdriver
from selenium.webdriver import ChromeOptions, Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains

# Set up Chrome options
chrome_options = ChromeOptions()
chrome_options.add_argument("--start-maximized")
chrome_options.add_experimental_option("excludeSwitches", ["enable-automation"])

# Start ChromeDriver
driver = webdriver.Chrome(options=chrome_options)

# Open the Twitter login page
url = 'https://x.com/i/flow/login'
driver.get(url)

# Your Twitter credentials
username_value  = 'JesseJin1998'
password_value  = 'Jesse1998.'

# Locate and fill the username input field
username = WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.CSS_SELECTOR, 'input[autocomplete="username"]')))
username.send_keys(username_value)
username.send_keys(Keys.ENTER)

# Handle potential additional login steps (e.g., captcha, phone number, etc.)
#time.sleep(3)  # Adjust the sleep time as needed for additional steps

# Locate and fill the password input field
password = WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.CSS_SELECTOR, 'input[name="password"]')))
password.send_keys(password_value)
password.send_keys(Keys.ENTER)

# Wait for the profile icon to be visible as an indication of a successful login
print("Logged in successfully.")

# Navigate to Elon Musk's page
twitter_url = 'https://x.com/elonmusk'
time.sleep(2)

# Store the latest tweet ID
last_tweet_id = None


driver.get(twitter_url)
time.sleep(5)  # Wait for the page to load
print("Navigate to page successfully.")

tweets = WebDriverWait(driver, 10).until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, 'article')))
if not tweets:
    print("No tweets found on the page.")


latest_tweet = tweets[1]

if not latest_tweet:
    print("No latest tweet found.")


tweet_link_elements = latest_tweet.find_elements(By.CSS_SELECTOR, 'a')

tweet_url = None
for link in tweet_link_elements:
    href = link.get_attribute('href')
    if 'status' in href:
        tweet_url = href
        break

tweet_content = latest_tweet.find_element(By.CSS_SELECTOR, 'div[lang]').text

if tweet_url:
    tweet_id = tweet_url.split('/')[-1]
    if tweet_id != last_tweet_id:
        last_tweet_id = tweet_id


# Get the latest tweet URL and content
latest_tweet_url, latest_tweet_content = tweet_content,tweet_url
if latest_tweet_url:
    print(f"Tweet_id: {last_tweet_id}")
    print(f"New Tweet URL: {latest_tweet_url}")
    print(f"New Tweet Content: {latest_tweet_content}")
    
else:
    print("No new tweet found.")
#driver.quit()
# Out:
# Logged in successfully.
# Navigate to page successfully.
# Tweet_id: 1796051160731676909
# New Tweet URL: Embrace cringe
# New Tweet Content: https://x.com/elonmusk/status/1796051160731676909

# %%
print(len(tweets))
for tweet in tweets:
    last_tweet_id = None
    tweet_link_elements = tweet.find_elements(By.CSS_SELECTOR, 'a')

    tweet_url = None
    for link in tweet_link_elements:
        href = link.get_attribute('href')
        if 'status' in href:
            tweet_url = href
            break
    tweet_content = tweet.find_element(By.CSS_SELECTOR, 'div[lang]').text
    
    # Locate the time element and get the datetime attribute
    from datetime import datetime
    tweet_time_element = tweet.find_element(By.CSS_SELECTOR, 'time')
    tweet_time = tweet_time_element.get_attribute('datetime')
    tweet_time = datetime.strptime(tweet_time, "%Y-%m-%dT%H:%M:%S.%fZ")


    if tweet_url:
        tweet_id = tweet_url.split('/')[-1]
        if tweet_id != last_tweet_id:
            last_tweet_id = tweet_id

    print(f"Tweet_id: {last_tweet_id}")
    print(f"New Tweet URL: {tweet_url}")
    print(f"New Tweet Time: {tweet_time}")
    print(f"New Tweet Content: {tweet_content}")
# Out:
# 6
# Tweet_id: 1795810940484510091
# New Tweet URL: https://x.com/qatarairways/status/1795810940484510091
# New Tweet Time: 2024-05-29 13:34:27
# New Tweet Content: Qatar Airways raises in-flight experience to new heights!
#
# We are proud to be the largest global airline and the first in the MENA region to collaborate with
# @SpaceX
#  @Starlink
#
#
# This complimentary, ground-breaking service will enhance our passengers' onboard experience with
# Tweet_id: 1796051160731676909
# New Tweet URL: https://x.com/elonmusk/status/1796051160731676909
# New Tweet Time: 2024-05-30 05:29:00
# New Tweet Content: Embrace cringe
# Tweet_id: 1795869252513087987
# New Tweet URL: https://x.com/elonmusk/status/1795869252513087987
# New Tweet Time: 2024-05-29 17:26:10
# New Tweet Content: Thanks Chamath!
# Tweet_id: 1795840604972429597
# New Tweet URL: https://x.com/SpaceX/status/1795840604972429597
# New Tweet Time: 2024-05-29 15:32:19
# New Tweet Content: Starship and Super Heavy loaded with more than 10 million pounds of propellant in a rehearsal ahead of Flight 4. Launch is targeted as early as June 5, pending regulatory approval
# Tweet_id: 1795817587118686230
# New Tweet URL: https://x.com/elonmusk/status/1795817587118686230
# New Tweet Time: 2024-05-29 14:00:52
# New Tweet Content: Starlink provides Internet connectivity in the air that is often better than being on the ground!
# Tweet_id: 1795809849638346883
# New Tweet URL: https://x.com/elonmusk/status/1795809849638346883
# New Tweet Time: 2024-05-29 13:30:07
# New Tweet Content: No kidding

# %%
content = f"""
**Tweet_id**: \n1796051160731676909\n
**New Tweet URL**: \nhttps://x.com/elonmusk/status/1796051160731676909\n
**New Tweet Time**: \n2024-05-30 05:29:00\n
**New Tweet Content**: \nEmbrace cringe\n
"""

# %%
import requests

# 发送消息的 API URL
url = 'https://sctapi.ftqq.com/SCT248743THUmNjCPaJzSYZB1Ox982ZzbZ.send'

# 要发送的消息内容
title = "Elon Musk " + "2024-05-30 05:29:00"
content = content

# 使用 POST 请求发送消息
response = requests.post(url, data={
    'title': title,
    'desp': content
})

# 检查响应状态码和内容
if response.status_code == 200:
    print("Message sent successfully.")
else:
    print(f"Failed to send message. Status code: {response.status_code}")
    print(response.text)
# Out:
# Message sent successfully.
